# %% [markdown]
# <!-- MELHOR FEATURES PARA UTILIZAR BASE ('500_10_10_1', 0.8544) -->

# %%
from sklearn.metrics import confusion_matrix
from sklearn.datasets import load_svmlight_file
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import reciprocal, uniform

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm

# %%
x, y = load_svmlight_file(f"../imdb_master/features/train_500_10_2_1.txt")
x_test, y_test = load_svmlight_file(f"../imdb_master/features/test_500_10_2_1.txt")

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.30, random_state=42)

# %%
model_svm = svm.SVC()
model_neigh = KNeighborsClassifier()

# %%
params = {"gamma": reciprocal(0.001, 0.1), "C": list(range(1, 100)), "kernel": ['rbf', 'poly']}
svm_cv = RandomizedSearchCV(model_svm, params, n_iter=100, verbose=2, cv=3)
svm_cv.fit(x_val, y_val)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END ......C=69, gamma=0.0010220795376011203, kernel=rbf; total time=  10.7s
# [CV] END ......C=69, gamma=0.0010220795376011203, kernel=rbf; total time=  10.4s
# [CV] END ......C=69, gamma=0.0010220795376011203, kernel=rbf; total time=   9.9s
# [CV] END .......C=84, gamma=0.09334380687343526, kernel=poly; total time=  10.6s
# [CV] END .......C=84, gamma=0.09334380687343526, kernel=poly; total time=  10.6s
# [CV] END .......C=84, gamma=0.09334380687343526, kernel=poly; total time=  10.2s
# [CV] END .......C=32, gamma=0.05781618463655485, kernel=poly; total time=  10.6s
# [CV] END .......C=32, gamma=0.05781618463655485, kernel=poly; total time=  10.5s
# [CV] END .......C=32, gamma=0.05781618463655485, kernel=poly; total time=  10.3s
# [CV] END .......C=27, gamma=0.08360505829680735, kernel=poly; total time=  10.7s
# [CV] END .......C=27, gamma=0.08360505829680735, kernel=poly; total time=  10.5s
# ...

# %%
print(svm_cv.best_params_)
# Out:
# {'C': 3, 'gamma': 0.020756759688054908, 'kernel': 'rbf'}
