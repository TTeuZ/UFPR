# %%
from sklearn.datasets import load_svmlight_file
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
from sklearn import svm

# %%
vector_sizes = [50, 100, 150, 200, 250, 300, 400, 500]
windows = [5, 10, 15, 20]
counts = [2, 5, 10]
methods = [1, 2]

# %%
preds = {}

for size in vector_sizes:
    for window in windows:
        for count in counts:
            for method in methods:
                print(f"Treinando o modelo com train_{size}_{window}_{count}_{method}.txt...")
                x, y = load_svmlight_file(f"../reviews_data/features/train_{size}_{window}_{count}_{method}.txt")
                x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.30, random_state=42)

                model = svm.SVC()
                model.fit(x_train, y_train)
                pred = model.predict(x_val)

                preds[f"{size}_{window}_{count}_{method}"] = pred
# Out:
# Treinando o modelo com train_50_5_2_1.txt...
# Treinando o modelo com train_50_5_2_2.txt...
# Treinando o modelo com train_50_5_5_1.txt...
# Treinando o modelo com train_50_5_5_2.txt...
# Treinando o modelo com train_50_5_10_1.txt...
# Treinando o modelo com train_50_5_10_2.txt...
# Treinando o modelo com train_50_10_2_1.txt...
# Treinando o modelo com train_50_10_2_2.txt...
# Treinando o modelo com train_50_10_5_1.txt...
# Treinando o modelo com train_50_10_5_2.txt...
# Treinando o modelo com train_50_10_10_1.txt...
# Treinando o modelo com train_50_10_10_2.txt...
# Treinando o modelo com train_50_15_2_1.txt...
# Treinando o modelo com train_50_15_2_2.txt...
# Treinando o modelo com train_50_15_5_1.txt...
# Treinando o modelo com train_50_15_5_2.txt...
# Treinando o modelo com train_50_15_10_1.txt...
# Treinando o modelo com train_50_15_10_2.txt...
# Treinando o modelo com train_50_20_2_1.txt...
# Treinando o modelo com train_50_20_2_2.txt...
# Treinando o modelo com train_50_20_5_1.txt...
# Treinando o modelo com train_50_20_5_2.txt...
# Treinando o modelo com train_50_20_10_1.txt...
# Treinando o modelo com train_50_20_10_2.txt...
# Treinando o modelo com train_100_5_2_1.txt...
# Treinando o modelo com train_100_5_2_2.txt...
# Treinando o modelo com train_100_5_5_1.txt...
# Treinando o modelo com train_100_5_5_2.txt...
# Treinando o modelo com train_100_5_10_1.txt...
# Treinando o modelo com train_100_5_10_2.txt...
# Treinando o modelo com train_100_10_2_1.txt...
# Treinando o modelo com train_100_10_2_2.txt...
# Treinando o modelo com train_100_10_5_1.txt...
# Treinando o modelo com train_100_10_5_2.txt...
# Treinando o modelo com train_100_10_10_1.txt...
# Treinando o modelo com train_100_10_10_2.txt...
# Treinando o modelo com train_100_15_2_1.txt...
# Treinando o modelo com train_100_15_2_2.txt...
# Treinando o modelo com train_100_15_5_1.txt...
# Treinando o modelo com train_100_15_5_2.txt...
# Treinando o modelo com train_100_15_10_1.txt...
# Treinando o modelo com train_100_15_10_2.txt...
# Treinando o modelo com train_100_20_2_1.txt...
# Treinando o modelo com train_100_20_2_2.txt...
# Treinando o modelo com train_100_20_5_1.txt...
# Treinando o modelo com train_100_20_5_2.txt...
# Treinando o modelo com train_100_20_10_1.txt...
# Treinando o modelo com train_100_20_10_2.txt...
# Treinando o modelo com train_150_5_2_1.txt...
# Treinando o modelo com train_150_5_2_2.txt...
# Treinando o modelo com train_150_5_5_1.txt...
# Treinando o modelo com train_150_5_5_2.txt...
# Treinando o modelo com train_150_5_10_1.txt...
# Treinando o modelo com train_150_5_10_2.txt...
# Treinando o modelo com train_150_10_2_1.txt...
# Treinando o modelo com train_150_10_2_2.txt...
# Treinando o modelo com train_150_10_5_1.txt...
# Treinando o modelo com train_150_10_5_2.txt...
# Treinando o modelo com train_150_10_10_1.txt...
# Treinando o modelo com train_150_10_10_2.txt...
# Treinando o modelo com train_150_15_2_1.txt...
# Treinando o modelo com train_150_15_2_2.txt...
# Treinando o modelo com train_150_15_5_1.txt...
# Treinando o modelo com train_150_15_5_2.txt...
# Treinando o modelo com train_150_15_10_1.txt...
# Treinando o modelo com train_150_15_10_2.txt...
# Treinando o modelo com train_150_20_2_1.txt...
# Treinando o modelo com train_150_20_2_2.txt...
# Treinando o modelo com train_150_20_5_1.txt...
# Treinando o modelo com train_150_20_5_2.txt...
# Treinando o modelo com train_150_20_10_1.txt...
# Treinando o modelo com train_150_20_10_2.txt...
# Treinando o modelo com train_200_5_2_1.txt...
# Treinando o modelo com train_200_5_2_2.txt...
# Treinando o modelo com train_200_5_5_1.txt...
# Treinando o modelo com train_200_5_5_2.txt...
# Treinando o modelo com train_200_5_10_1.txt...
# Treinando o modelo com train_200_5_10_2.txt...
# Treinando o modelo com train_200_10_2_1.txt...
# Treinando o modelo com train_200_10_2_2.txt...
# Treinando o modelo com train_200_10_5_1.txt...
# Treinando o modelo com train_200_10_5_2.txt...
# Treinando o modelo com train_200_10_10_1.txt...
# Treinando o modelo com train_200_10_10_2.txt...
# Treinando o modelo com train_200_15_2_1.txt...
# Treinando o modelo com train_200_15_2_2.txt...
# Treinando o modelo com train_200_15_5_1.txt...
# Treinando o modelo com train_200_15_5_2.txt...
# Treinando o modelo com train_200_15_10_1.txt...
# Treinando o modelo com train_200_15_10_2.txt...
# Treinando o modelo com train_200_20_2_1.txt...
# Treinando o modelo com train_200_20_2_2.txt...
# Treinando o modelo com train_200_20_5_1.txt...
# Treinando o modelo com train_200_20_5_2.txt...
# Treinando o modelo com train_200_20_10_1.txt...
# Treinando o modelo com train_200_20_10_2.txt...
# Treinando o modelo com train_250_5_2_1.txt...
# Treinando o modelo com train_250_5_2_2.txt...
# Treinando o modelo com train_250_5_5_1.txt...
# Treinando o modelo com train_250_5_5_2.txt...
# Treinando o modelo com train_250_5_10_1.txt...
# Treinando o modelo com train_250_5_10_2.txt...
# Treinando o modelo com train_250_10_2_1.txt...
# Treinando o modelo com train_250_10_2_2.txt...
# Treinando o modelo com train_250_10_5_1.txt...
# Treinando o modelo com train_250_10_5_2.txt...
# Treinando o modelo com train_250_10_10_1.txt...
# Treinando o modelo com train_250_10_10_2.txt...
# Treinando o modelo com train_250_15_2_1.txt...
# Treinando o modelo com train_250_15_2_2.txt...
# Treinando o modelo com train_250_15_5_1.txt...
# Treinando o modelo com train_250_15_5_2.txt...
# Treinando o modelo com train_250_15_10_1.txt...
# Treinando o modelo com train_250_15_10_2.txt...
# Treinando o modelo com train_250_20_2_1.txt...
# Treinando o modelo com train_250_20_2_2.txt...
# Treinando o modelo com train_250_20_5_1.txt...
# Treinando o modelo com train_250_20_5_2.txt...
# Treinando o modelo com train_250_20_10_1.txt...
# Treinando o modelo com train_250_20_10_2.txt...
# Treinando o modelo com train_300_5_2_1.txt...
# Treinando o modelo com train_300_5_2_2.txt...
# Treinando o modelo com train_300_5_5_1.txt...
# Treinando o modelo com train_300_5_5_2.txt...
# Treinando o modelo com train_300_5_10_1.txt...
# Treinando o modelo com train_300_5_10_2.txt...
# Treinando o modelo com train_300_10_2_1.txt...
# Treinando o modelo com train_300_10_2_2.txt...
# Treinando o modelo com train_300_10_5_1.txt...
# Treinando o modelo com train_300_10_5_2.txt...
# Treinando o modelo com train_300_10_10_1.txt...
# Treinando o modelo com train_300_10_10_2.txt...
# Treinando o modelo com train_300_15_2_1.txt...
# Treinando o modelo com train_300_15_2_2.txt...
# Treinando o modelo com train_300_15_5_1.txt...
# Treinando o modelo com train_300_15_5_2.txt...
# Treinando o modelo com train_300_15_10_1.txt...
# Treinando o modelo com train_300_15_10_2.txt...
# Treinando o modelo com train_300_20_2_1.txt...
# Treinando o modelo com train_300_20_2_2.txt...
# Treinando o modelo com train_300_20_5_1.txt...
# Treinando o modelo com train_300_20_5_2.txt...
# Treinando o modelo com train_300_20_10_1.txt...
# Treinando o modelo com train_300_20_10_2.txt...
# Treinando o modelo com train_400_5_2_1.txt...
# Treinando o modelo com train_400_5_2_2.txt...
# Treinando o modelo com train_400_5_5_1.txt...
# Treinando o modelo com train_400_5_5_2.txt...
# Treinando o modelo com train_400_5_10_1.txt...
# Treinando o modelo com train_400_5_10_2.txt...
# Treinando o modelo com train_400_10_2_1.txt...
# Treinando o modelo com train_400_10_2_2.txt...
# Treinando o modelo com train_400_10_5_1.txt...
# Treinando o modelo com train_400_10_5_2.txt...
# Treinando o modelo com train_400_10_10_1.txt...
# Treinando o modelo com train_400_10_10_2.txt...
# Treinando o modelo com train_400_15_2_1.txt...
# Treinando o modelo com train_400_15_2_2.txt...
# Treinando o modelo com train_400_15_5_1.txt...
# Treinando o modelo com train_400_15_5_2.txt...
# Treinando o modelo com train_400_15_10_1.txt...
# Treinando o modelo com train_400_15_10_2.txt...
# Treinando o modelo com train_400_20_2_1.txt...
# Treinando o modelo com train_400_20_2_2.txt...
# Treinando o modelo com train_400_20_5_1.txt...
# Treinando o modelo com train_400_20_5_2.txt...
# Treinando o modelo com train_400_20_10_1.txt...
# Treinando o modelo com train_400_20_10_2.txt...
# Treinando o modelo com train_500_5_2_1.txt...
# Treinando o modelo com train_500_5_2_2.txt...
# Treinando o modelo com train_500_5_5_1.txt...
# Treinando o modelo com train_500_5_5_2.txt...
# Treinando o modelo com train_500_5_10_1.txt...
# Treinando o modelo com train_500_5_10_2.txt...
# Treinando o modelo com train_500_10_2_1.txt...
# Treinando o modelo com train_500_10_2_2.txt...
# Treinando o modelo com train_500_10_5_1.txt...
# Treinando o modelo com train_500_10_5_2.txt...
# Treinando o modelo com train_500_10_10_1.txt...
# Treinando o modelo com train_500_10_10_2.txt...
# Treinando o modelo com train_500_15_2_1.txt...
# Treinando o modelo com train_500_15_2_2.txt...
# Treinando o modelo com train_500_15_5_1.txt...
# Treinando o modelo com train_500_15_5_2.txt...
# Treinando o modelo com train_500_15_10_1.txt...
# Treinando o modelo com train_500_15_10_2.txt...
# Treinando o modelo com train_500_20_2_1.txt...
# Treinando o modelo com train_500_20_2_2.txt...
# Treinando o modelo com train_500_20_5_1.txt...
# Treinando o modelo com train_500_20_5_2.txt...
# Treinando o modelo com train_500_20_10_1.txt...
# Treinando o modelo com train_500_20_10_2.txt...

# %%
accuracys = {}
max_accuracy = ("", 0)

for pred in preds:
    accuracy = accuracy_score(y_val, preds[pred])

    if accuracy > max_accuracy[1]:
        max_accuracy = (pred, accuracy)

    accuracys[pred] = accuracy_score(y_val, preds[pred])

# %%
max_accuracy
# Out:
# ('500_10_10_1', 0.8544)
