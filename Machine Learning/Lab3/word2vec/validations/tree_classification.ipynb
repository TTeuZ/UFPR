# %%
from sklearn.datasets import load_svmlight_file
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
from sklearn import tree

# %%
x, y = load_svmlight_file(f"../imdb_master/features/train_500_10_2_1.txt")
x_test, y_test = load_svmlight_file(f"../imdb_master/features/test_500_10_2_1.txt")

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.30, random_state=42)

# %%
accuracys = []

for depth in range (1, 11):
    model = tree.DecisionTreeClassifier(max_depth=depth)
    model.fit(x_train, y_train)
    pred = model.predict(x_val)
    accuracys.append(accuracy_score(y_val, pred))

# %%
x = range(1, len(accuracys) + 1)
y = accuracys

plt.title('Validação do Depth para o Tree Regressor')
plt.plot(x, y)
plt.show()
